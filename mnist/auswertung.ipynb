# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_default = pd.read_excel("../data/Auswertung.xlsx", sheet_name="Unverändert", index_col="Modifikation")
df_manipuliert = pd.read_excel("../data/Auswertung.xlsx", sheet_name="Manipuliert", index_col="Modifikation")

df_rauschen = pd.read_excel("../data/Auswertung.xlsx", sheet_name="Rauschen", index_col="Modifikation")
df_rauschen_100 = df_rauschen[df_rauschen.Pixel==100].drop("Pixel", axis=1)
df_rauschen_200 = df_rauschen[df_rauschen.Pixel==200].drop("Pixel", axis=1)

df_unscharf = pd.read_excel("../data/Auswertung.xlsx", sheet_name="Unschärfe", index_col="Modifikation")
df_unscharf_4 = df_unscharf[df_unscharf.Matrix==4].drop("Matrix", axis=1)
df_unscharf_5 = df_unscharf[df_unscharf.Matrix==5].drop("Matrix", axis=1)
df_unscharf_6 = df_unscharf[df_unscharf.Matrix==6].drop("Matrix", axis=1)

df_translation = pd.read_excel("../data/Auswertung.xlsx", sheet_name="Translation", index_col="Modifikation")
df_translation_3 = df_translation[df_translation.Pixel==3].drop("Pixel", axis=1)
df_translation_6 = df_translation[df_translation.Pixel==6].drop("Pixel", axis=1)
df_translation_vertical = df_translation[df_translation.Pixel=="vertikal"].drop("Pixel", axis=1)

df_rotation = pd.read_excel("../data/Auswertung.xlsx", sheet_name="Rotation", index_col="Modifikation")
df_rotation_90 = df_rotation[df_rotation.Rotation==90].drop("Rotation", axis=1)
df_rotation_180 = df_rotation[df_rotation.Rotation==180].drop("Rotation", axis=1)

# %%
df_default.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df_manipuliert.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df_rauschen_100.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df_rauschen_200.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df_unscharf_4.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df_unscharf_6.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df_translation_3.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df_translation_6.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df_translation_vertical.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df_rotation_90.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>

# %%
df_rotation_180.T.plot(kind="bar", figsize=(15,8))
# Out:
# <AxesSubplot:>
